# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt
import seaborn as sns
import os
import pandas as pd
print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 6
#       2 # import numpy as np
#       3 # import matplotlib.pyplot as mlt
#       4 # import seaborn as sns
#       5 # import os
# ----> 6 import pandas as pd
#       7 print(pd.__version__)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# df = pd.read_csv('zomato.csv')
print(os.getcwd())
print(os.listdir())
pd.read_excel('file.xlsx', engine='openpyxl')
# Out:
# c:\Dev\AiML\EDA Week
# ['venv', 'zomato.csv', 'zomato.ipynb', 'Zomatodataset', 'Zomatodataset.zip']

# %%
import pandas as pd
pd.read_excel('Country-Code.xlsx', engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_58790/52034406.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 pd.read_excel('Country-Code.xlsx', engine='openpyxl')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...
